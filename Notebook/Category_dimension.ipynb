# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:\\Users\\User\\Documents\\GitHub\\incident_trend_root_cause_analysis\\Data\\incident_data.csv')
data
# Out:
#       incident_id       created_at      resolved_at    severity     category  \
# 0      INC0002915    3/6/2016 8:50  3/11/2016 16:53  2 - Medium  Category 45
# 1      INC0002925    3/6/2016 9:40    3/6/2016 9:46  2 - Medium  Category 43
# 2      INC0002928   3/6/2016 10:27   3/6/2016 10:31  2 - Medium  Category 32
# 3      INC0002933   3/6/2016 10:52    3/7/2016 2:04  2 - Medium  Category 26
# 4      INC0002934   3/6/2016 10:52   3/6/2016 22:15  2 - Medium  Category 26
# ...           ...              ...              ...         ...          ...
# 23357  INC0031987   5/23/2016 8:40  5/24/2016 15:41  2 - Medium  Category 46
# 23358  INC0031989   5/23/2016 8:41  5/23/2016 10:44  2 - Medium  Category 24
# 23359  INC0024048   4/29/2016 9:51   4/29/2016 9:57  2 - Medium  Category 46
# 23360  INC0024159  4/29/2016 11:49  4/29/2016 12:02  2 - Medium  Category 53
# 23361  INC0024412   4/30/2016 1:34   4/30/2016 1:39  2 - Medium  Category 46
#
# ...

# %%
data["category"] = data["category"].str.extract(r'(\d+)')
data["category"] = pd.to_numeric(data["category"], errors="coerce")

# %%
data
# Out:
#       incident_id       created_at      resolved_at    severity  category  \
# 0      INC0002915    3/6/2016 8:50  3/11/2016 16:53  2 - Medium      45.0
# 1      INC0002925    3/6/2016 9:40    3/6/2016 9:46  2 - Medium      43.0
# 2      INC0002928   3/6/2016 10:27   3/6/2016 10:31  2 - Medium      32.0
# 3      INC0002933   3/6/2016 10:52    3/7/2016 2:04  2 - Medium      26.0
# 4      INC0002934   3/6/2016 10:52   3/6/2016 22:15  2 - Medium      26.0
# ...           ...              ...              ...         ...       ...
# 23357  INC0031987   5/23/2016 8:40  5/24/2016 15:41  2 - Medium      46.0
# 23358  INC0031989   5/23/2016 8:41  5/23/2016 10:44  2 - Medium      24.0
# 23359  INC0024048   4/29/2016 9:51   4/29/2016 9:57  2 - Medium      46.0
# 23360  INC0024159  4/29/2016 11:49  4/29/2016 12:02  2 - Medium      53.0
# 23361  INC0024412   4/30/2016 1:34   4/30/2016 1:39  2 - Medium      46.0
#
#       team_assigned closed_code  resolution_time_hour    shift  hour  \
# ...

# %%
data["closed_code"] = data["closed_code"].str.extract(r'(\d+)')
data["closed_code"] = pd.to_numeric(data["closed_code"], errors="coerce")

# %%
data
# Out:
#       incident_id       created_at      resolved_at    severity  category  \
# 0      INC0002915    3/6/2016 8:50  3/11/2016 16:53  2 - Medium      45.0
# 1      INC0002925    3/6/2016 9:40    3/6/2016 9:46  2 - Medium      43.0
# 2      INC0002928   3/6/2016 10:27   3/6/2016 10:31  2 - Medium      32.0
# 3      INC0002933   3/6/2016 10:52    3/7/2016 2:04  2 - Medium      26.0
# 4      INC0002934   3/6/2016 10:52   3/6/2016 22:15  2 - Medium      26.0
# ...           ...              ...              ...         ...       ...
# 23357  INC0031987   5/23/2016 8:40  5/24/2016 15:41  2 - Medium      46.0
# 23358  INC0031989   5/23/2016 8:41  5/23/2016 10:44  2 - Medium      24.0
# 23359  INC0024048   4/29/2016 9:51   4/29/2016 9:57  2 - Medium      46.0
# 23360  INC0024159  4/29/2016 11:49  4/29/2016 12:02  2 - Medium      53.0
# 23361  INC0024412   4/30/2016 1:34   4/30/2016 1:39  2 - Medium      46.0
#
#       team_assigned  closed_code  resolution_time_hour    shift  hour  \
# ...

# %%
data["team_assigned"] = data["team_assigned"].str.extract(r'(\d+)')
data["team_assigned"] = pd.to_numeric(data["team_assigned"], errors="coerce")

# %%
data
# Out:
#        incident_id       created_at      resolved_at    severity  category  \
# 0             2915    3/6/2016 8:50  3/11/2016 16:53  2 - Medium      45.0
# 1             2925    3/6/2016 9:40    3/6/2016 9:46  2 - Medium      43.0
# 2             2928   3/6/2016 10:27   3/6/2016 10:31  2 - Medium      32.0
# 3             2933   3/6/2016 10:52    3/7/2016 2:04  2 - Medium      26.0
# 4             2934   3/6/2016 10:52   3/6/2016 22:15  2 - Medium      26.0
# ...            ...              ...              ...         ...       ...
# 23357        31987   5/23/2016 8:40  5/24/2016 15:41  2 - Medium      46.0
# 23358        31989   5/23/2016 8:41  5/23/2016 10:44  2 - Medium      24.0
# 23359        24048   4/29/2016 9:51   4/29/2016 9:57  2 - Medium      46.0
# 23360        24159  4/29/2016 11:49  4/29/2016 12:02  2 - Medium      53.0
# 23361        24412   4/30/2016 1:34   4/30/2016 1:39  2 - Medium      46.0
#
# ...

# %%
data["incident_id"] = data["incident_id"].str.extract(r'(\d+)')
data["incident_id"] = pd.to_numeric(data["incident_id"], errors="coerce")

# %%
x= data['closed_code']
y= data['team_assigned']
plt.bar(x,y,color='blue')
plt.title("root cause category trend")
plt.xlabel("root cause")
plt.ylabel("team")
plt.show()

# %%
x= data['incident_id']
y= data['hour']
plt.bar(x,y,color='blue')
plt.title("root cause category trend")
plt.xlabel("incidnets")
plt.ylabel("reslotion time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31356\3389286818.py in ?()
# ----> 1 x= data['incident_id'].log()
#       2 y= data['hour']
#       3 plt.bar(x,y,color='blue')
#       4 plt.title("root cause category trend")
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'log'
